# %% [markdown]
# # <font color='blue'>Data Science Academy - Python Fundamentos - Capítulo 6</font>
#
# ## Download: http://github.com/dsacademybr

# %%
# Versão da Linguagem Python
from platform import python_version
print('Versão da Linguagem Python Usada Neste Jupyter Notebook:', python_version())
# Out:
# Versão da Linguagem Python Usada Neste Jupyter Notebook: 3.8.3

# %% [markdown]
# ### Gráficos

# %%
# Instala a versão exata do pacote matplotlib
# !pip install -q -U matplotlib==3.2.1
# Out:
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# WARNING: You are using pip version 20.2.3; however, version 20.2.4 is available.
# You should consider upgrading via the 'c:\program files (x86)\python37-32\python.exe -m pip install --upgrade pip' command.

# %%
import matplotlib as mat
mat.__version__
# Out:
# '3.2.2'

# %%
import sqlite3
import random
import datetime
import matplotlib.pyplot as plt
# Comando para a execução do gráfico dentro do próprio jupyter notebook
# %matplotlib notebook
 
# Criando uma conexão
conn = sqlite3.connect('dsa.db')   

# Criando um cursor
c = conn.cursor()
 
# Função para criar uma tabela
def create_table():
    c.execute('CREATE TABLE IF NOT EXISTS produtos(id INTEGER PRIMARY KEY AUTOINCREMENT NOT NULL, date TEXT, '\
              'prod_name TEXT, valor REAL)')
     
# Função para inserir uma linha
def data_insert():
    c.execute("INSERT INTO produtos VALUES(now, 'Teclado', 130 )")
    conn.commit()
    c.close()
    conn.close()
    
# Usando variáveis para inserir dados    
def data_insert_var():
    new_date = datetime.datetime.now()
    new_prod_name = 'monitor'
    new_valor = random.randrange(50,100)
    c.execute("INSERT INTO produtos (date, prod_name, valor) VALUES (?, ?, ?, ?)", 
              (new_date, new_prod_name, new_valor))
    conn.commit()
    
# Leitura de dados
def leitura_todos_dados():
    c.execute("SELECT * FROM PRODUTOS")
    for linha in c.fetchall():
        print(linha)
        
# Leitura de registros específicos
def leitura_registros():
    c.execute("SELECT * FROM PRODUTOS WHERE valor > 60.0")
    for linha in c.fetchall():
        print(linha)      
        
# Leitura de colunas específicos
def leitura_colunas():
    c.execute("SELECT * FROM PRODUTOS")
    for linha in c.fetchall():
        print(linha[3])  
        
# Update
def atualiza_dados():
    c.execute("UPDATE produtos SET valor = 70.00 WHERE valor > 80.0")
    conn.commit()
    
# Delete
def remove_dados():
    c.execute("DELETE FROM produtos WHERE valor = 62.0")
    conn.commit()

# Gerar gráfico com os dados no banco de dados
def dados_grafico():
    c.execute('SELECT id, valor FROM produtos')
    ids = []
    valores = []
    dados = c.fetchall()
    for linha in dados:
        ids.append(linha[0])
        valores.append(linha[1])
        
    plt.bar(ids, valores)
    plt.show()

# %%
# Gerando gráficos
dados_grafico()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # <font color='blue'>Visualização de Dados e Design de Dashboards</font>
#
# https://www.datascienceacademy.com.br/course?courseid=cincia-de-dados-aplicada

# %% [markdown]
# ### Introdução
#
# - Formação Cientista de Dados 01:34
# - Perguntas e Respostas
# - Navegando pela Data Science Academy 06:20
# - Suporte e Canais de Comunicação
# - Termos e Condições de Uso
# - Introdução ao Curso - Como Chegamos Até Aqui 04:35
# - Introdução ao Curso - Conteúdo Programático 07:25
# - Pré-Requisitos (recomendados) 03:06
# - Ferramentas Utilizadas No Curso 03:57
# - Recomendações e Objetivos ao Final do Curso 04:33
# - O Que é Visualização de Dados? 05:52
# - Benefícios da Visualização de Dados 05:22
# - Compreendendo sua Audiência 07:46
# - O Que é Storytelling? 05:30
# - E Como Fazemos Storytelling? 09:13
# - Definindo o Propósito da Visualização de Dados 07:02
# - Escolhendo o Melhor Design para a Visualização de Dados - O Aspecto Humano da Visualização 05:27
# - Escolhendo o Melhor Design para a Visualização de Dados - A Importância das Imagens 04:40
# - Design Thinking para Cientistas de Dados 06:36
# - Fases do Design Thinking 05:44
# - E-book - Cientista de Dados, O Contador de Histórias 05:01
# - Como Tratar a Mudança de Versão de Software
# - Bibliografia, Referências e Links Úteis
# - E-book Guia de Estudo e Aprendizagem da Data Science Academy

# %% [markdown]
# ### Métodos de Visualização
#
# - Introdução 08:36
# - Técnicas de Apresentação - Parte 1/3
# - Técnicas de Apresentação - Parte 2/3
# - Técnicas de Apresentação - Parte 3/3
# - Por que Seu Cérebro Precisa de Visualização de Dados? 05:32
# - Que Tipo de Gráfico Escolher Para Sumarizar Meus Dados? 06:09
# - Tipos de Dados 01:39
# - Visual Encodings 05:18
# - Ferramentas de Visualização de Dados
# - O Processo de Criação de Charts e Plots 02:14
# - Visualização de Dados Numéricos e Não-Numéricos 05:06
# - Gráficos Padrões (Barra, Coluna, Linha, Pizza, Rosca, Area, Stacked Area) 07:05
# - Gráficos Comparativos (Bubble Plots, Radar Plot, Waterfall Plot, Packed Circle Diagrams) 03:39
# - Gráficos Espaciais e Mapas (Tree Maps, Choropleths, Point Maps, Raster Surface Maps) 06:14
# - Plots (Histogramas, Scatter Plots, Scatter Plots Matrix) 03:24
# - Word Clouds (Nuvem de Palavras) 02:06
# - Sankey Diagrams 01:03
# - Stream Graphs 02:36
# - Heatmaps 01:27
# - Gantt Charts 01:50
# - Sunburst Diagram 00:55
# - Box and Whisker Plot 01:22
# - Density Plot 01:06
# - Network Diagram 01:19
# - Melhorando a Leitura e Entendimento de Gráficos 07:32
# - Infográficos
# - Galeria de Exemplos com Outros Tipos de Gráficos
# - Slides Módulo 02
# - Quiz 5 questões
# - Bibliografia, Referências e Links Úteis

# %% [markdown]
# ### Organização Visual
#
# - Introdução 08:15
# - Identidade Visual x Design Gráfico 03:43
# - UI Design x UX Design 07:50
# - Visualizando Dados Multidimensionais 04:23
# - Técnicas de Visualização de Dados Multidimensionais - Projeções Geométricas 03:51
# - Técnicas de Visualização de Dados Multidimensionais - Técnicas Baseadas em Pixels 06:48
# - Técnicas de Visualização de Dados Multidimensionais - Iconografia 03:05
# - Técnicas de Visualização de Dados Multidimensionais - Hierarquia de Visualização 02:32
# - Técnicas de Visualização de Dados Multidimensionais - Grafos 01:52
# - Visualização de Dados e Big Data Analytics 08:23
# - Escolha de Técnicas de Visualização de Dados - Parte 1/2 06:11
# - Escolha de Técnicas de Visualização de Dados - Parte 2/2 10:59
# - Web Semântica 05:55
# - Visualização de Dados com Realidade Aumentada 06:35
# - Slides Módulo 03
# - Quiz 5 questões
# - Bibliografia, Referências e Links úteis

# %% [markdown]
# ### Dashboard Design
#
# - Introdução 03:49
# - O que são Dashboards? 06:54
# - Dashboards Operacionais x Dashboards Analíticos x Dashboards Executivos 04:26
# - Tipos de Dashboards 04:34
# - O Processo de Design de Dashboards 07:50
# - Desenvolvimento do Layout 09:36
# - Características de um Dashboard Eficiente 03:57
# - Dashboards - Desenvolver ou Usar Soluções Proprietárias 02:32
# - Storyboard 05:14
# - Narrativa Visual 04:01
# - Erros Comuns no Design de Dashboards 04:19
# - Analytics Dashboard 01:35
# - Real-Time Dashboards 02:43
# - Alinhando a Terminologia: Dataviz, BI, Reporting, Analytics e KPI's 01:34
# - Mini-Projeto 1 - Construção de Real-Time Dashboard
# - Construindo um Real-Time Dashboard - Parte 1/3 08:55
# - Construindo um Real-Time Dashboard - Parte 2/3 08:12
# - Construindo um Real-Time Dashboard - Parte 3/3 07:03
# - Slides Módulo 04
# - Quiz 5 questões
# - Bibliografia, Referências e Links úteis

# %% [markdown]
# ### Visualização de Dados com D3.js
#
# - Introdução 06:34
# - Introduzindo a Biblioteca D3.js para Visualização de Dados 10:31
# - Criando Elementos com D3 - Parte 1/3 07:40
# - Criando Elementos com D3 - Parte 2/3 05:47
# - Criando Elementos com D3 - Parte 3/3 06:00
# - O que é SVG?
# - Arrays e Objetos - Parte 1/2 09:06
# - Arrays e Objetos - Parte 2/2 06:14
# - Função Filter 04:53
# - Função Map 03:19
# - Funções Especiais do D3.js 04:54
# - Inicializando um Chart com SVG 08:10
# - Construindo um Bar Chart 05:50
# - Ajustando a Escala e Alterando o CSS 06:56
# - Adicionando Texto ao Chart 03:15
# - Criando uma Função para Construção de Charts 06:18
# - Definindo as Margens do Chart 07:11
# - Criando Gráficos Bidimensionais 05:05
# - Adicionando Cores e Eixos x e y 09:09
# - Invertendo os Eixos 04:11
# - Rotacionando os Eixos 05:40
# - Adicionando Labels 06:00
# - Adicionando Interatividade ao Gráfico 11:47
# - Criando um Plot de Series Temporais 10:39
# - Criando um Scatter Plot Interativo - Parte 1/2 04:08
# - Criando um Scatter Plot Interativo - Parte 2/2 06:04
# - Criando Aplicação de Visualização 08:24
# - Todos os Arquivos da Aplicação de Visualização
# - Criando Charts Reutilizáveis - Layout Padrão 04:53
# - Criando Charts Reutilizáveis - Adicionando Código de Barras 03:52
# - Criando Charts Reutilizáveis - Carregando Código de Barras com Arquivo CSV 04:08
# - Construindo um Radar Chart Interativo 08:09
# - Construindo um Bubble Chart com Legenda a partir de Arquivo JSON 05:46
# - Criando Gráfico com Slider 06:32
# - Adicionando um Color Picker 05:47
# - Adicionando Tooltips ao Gráfico 07:08
# - Criando Área de Seleção Interativa 06:49
# - Criando Mapas com Dados Geoespaciais, Integracão D3 e Mapbox 08:48
# - Criando Choropleth Map 03:29
# - Criando Heatmaps 05:42
# - Construindo Mapas Avançados 06:41
# - Criando Seções no Dashboard - Parte 1/2 06:32
# - Criando Seções no Dashboard - Parte 2/2 02:51
# - Construindo um Dashboard 04:44
# - Mini-Projeto 2 - Criando Visualizações de Dados do Twitter em Tempo Real
# - Slides Módulo 05
# - Quiz 5 questões
# - Bibliografia, Referências e Links úteis

# %% [markdown]
# ### Visualização de Dados com R
#
# - Introdução 03:12
# - Base Plotting System 04:46
# - Compreendendo a Gramática dos Gráficos 03:53
# - Biblioteca ggplot2 03:08
# - Função Plot e Paleta de Cores - Parte 1/3 05:53
# - Função Plot e Paleta de Cores - Parte 2/3 06:10
# - Função Plot e Paleta de Cores - Parte 3/3 07:34
# - Gerando Plots Padrões (Histogramas, Boxplots e Scatterplots) - Parte 1/2 06:20
# - Gerando Plots Padrões (Histogramas, Boxplots e Scatterplots) - Parte 2/2 04:16
# - ggplot2 - Definindo as Camadas 07:41
# - ggplot2 - Colocando Gráficos Lado a Lado na Área de Desenho 08:36
# - ggplot2 - Plot Multivariado 03:57
# - ggplot2 - Scatter Plots e Scatter Plots 3D 04:40
# - ggplot2 - Barplots, Histogramas e Polígonos de Frequência 05:21
# - ggplot2 - Personalizando os Gráficos 06:10
# - ggplot2 - Facets, Extra Grid e Plotly 05:13
# - Heat Maps 08:07
# - Correlation Heat Maps 04:16
# - Sumarizando Dados Multivariados em um único Heat Map 04:43
# - Countour Plot e Filled Countour Plot 04:31
# - Surface Plots 3D 03:15
# - Visualizando Séries Temporais com Calendar Heat Maps 09:27
# - Heat Maps com Plotly 04:15
# - Criando Gráficos com Lattice - Parte 1/2 04:00
# - Criando Gráficos com Lattice - Parte 2/2 06:25
# - Boxplots e Violin Plots 06:05
# - Gráficos com ggvis - Parte 1/2 06:06
# - Gráficos com ggvis - Parte 2/2 06:24
# - Construindo Mapas Interativos com ggvis 03:37
# - Construindo Mapas Interativos com ggvis e Shiny 07:02
# - Criando Mapas com RGoogleMaps - Parte 1/2 05:29
# - Criando Mapas com RGoogleMaps - Parte 2/2 04:04
# - Mapeando o Trânsito com Heat Maps e RGoogleMaps 07:24
# - Gráficos Interativos de Séries Temporais com Dygraphs 04:48
# - Criando Aplicações Web Interativas com Shiny Dashboard - Google Analytics - Parte 1/3 08:23
# - Criando Aplicações Web Interativas com Shiny Dashboard - Google Analytics - Parte 2/3 07:23
# - Criando Aplicações Web Interativas com Shiny Dashboard - Google Analytics - Parte 3/3 04:05
# - Slides Módulo 06
# - Quiz 5 questões
# - Bibliografia, Referências e Links úteis

# %% [markdown]
# ### Visualização de Dados com Python
#
# - Introdução 02:34
# - Preparando o Ambiente 06:42
# - Plots com Matplotlib - Parte 1/3 05:51
# - Plots com Matplotlib - Parte 2/3 07:48
# - Plots com Matplotlib - Parte 3/3 09:41
# - Linha de Regressão com Matplotlib 07:10
# - Scatter Plot 3D e Plotly 08:36
# - Configuração e Customização Avançada do Matplotlib 09:52
# - Criando Módulos Personalizados 06:43
# - Carregando e Normalizando os Dados 09:20
# - Plots e GridSpec 04:03
# - Radar Plot 03:46
# - Plots Combinados 04:42
# - Construindo um Dashboard com Matplotlib 05:31
# - Usando o Pacote ggplot no Python 09:04
# - Criando Gráficos Estatísticos com Seaborn - Parte 1/3 10:48
# - Criando Gráficos Estatísticos com Seaborn - Parte 2/3 06:13
# - Criando Gráficos Estatísticos com Seaborn - Parte 3/3 07:50
# - Criando SVG Charts com Svgwrite 06:02
# - Criando SVG Charts com PyGal 08:50
# - Mapas Interativos com Geoplotlib 10:06
# - Mapa Interativo com Uso do Teclado 05:10
# - Construindo um Mapa com Animação Automática 06:31
# - Quadtree 02:54
# - Mapeamento de Rotas - Carga e Manipulação de Dados 07:15
# - Mapeamento de Rotas - Analisando os Dados 03:55
# - Mapeamento de Rotas - Construindo os Mapas 05:38
# - Mini-Projeto 3 - Web Analytics Dashboard
# - Slides Módulo 07
# - Quiz 5 questões
# - Bibliografia, Referências e Links úteis

# %% [markdown]
# ### Visualização de Dados com Tableau
#
# - Introdução 03:13
# - Tableau Desktop e Tableau Public 09:37
# - Tableau Desktop x Tableau Public 04:59
# - Criando um Gráfico de Vendas em Apenas 3 Passos 07:59
# - Fontes de Dados e Navegando pelo Tableau 07:49
# - Criando Varios Gráficos Simultaneamente 09:02
# - Criando Campos Calculados 07:25
# - Customizando o Gráfico - Paleta de Cores 05:22
# - Customizando o Gráfico - Labels e Formatação 05:39
# - Customizando o Gráfico - Caption, Título e Summary 03:15
# - Exportando o Gráfico Para o Word 03:26
# - Inner, Left, Right e Full Outer Join 07:14
# - Definindo Hierarquia 04:09
# - Criando um Mapa do Brasil 04:14
# - Criando um Mapa do Brasil com Total de Vendas Por Cidade 06:12
# - Construindo um Dashboard - Gráfico Individual - Margem de Lucro por Estado 08:35
# - Construindo um Dashboard - Gráfico Individual - Lucratividade Por Cliente 08:16
# - Construindo um Dashboard - Montagem do Painel 06:09
# - Adicionando Interatividade ao seu Dashboard 05:04
# - Preparando um Dashboard para Storyline - Corrigindo Erros no Dataset 09:31
# - Preparando um Dashboard para Storyline - Trabalhando com Porcentagem 02:30
# - Preparando um Dashboard para Storyline - Convertendo os Bins 06:31
# - Preparando um Dashboard para Storyline - Adicionando Parâmetros aos Gráficos 07:35
# - Preparando um Dashboard para Storyline - Tree Map 04:23
# - Preparando um Dashboard para Storyline - Montagem do Painel 09:47
# - Como Apresentar uma Storyline - Parte 1/2 07:25
# - Como Apresentar uma Storyline - Parte 2/2 04:23
# - Criando um Portfólio com Public Tableau 06:05
# - Bonus - Conectando em Um Banco de Dados Oracle e Gerando Visualizações 05:30
# - Mini-Projeto 4 - Construindo uma Visualização de Dados para Apresentação Executiva
# - Slides Módulo 08
# - Quiz 5 questões
# - Bibliografia, Referências e Links úteis

# %% [markdown]
# ### Visualização de Dados com Qlik Sense
#
# - Introdução 02:34
# - Conhecendo o Qlik Sense 10:39
# - Qlik View x Tableau x Power BI 04:54
# - Instalando Qlik Sense Desktop 03:08
# - Navegando Pelo Qlik Sense Hub 08:49
# - Dimensões e Medidas 03:54
# - Criando uma App 05:27
# - Importando e Carregando Dados 05:09
# - Associando Tabelas 03:48
# - Gráficos Para Avaliar o Orçamento de uma Startup 06:13
# - Customizando os Gráficos 04:13
# - Slides Módulo 09
# - Bibliografia, Referências e Links úteis

# %% [markdown]
# ### Outras Ferramentas de Visualização
#
# - Como Escolher uma Ferramenta de Visualização? 07:53
# - Chart.js 03:37
# - Leaflet 03:12
# - Datawrapper 04:28
# - Dygraphs 02:25
# - Highcharts 03:30
# - Google Charts 02:36
# - Polymaps 01:13
# - Weka 03:29
# - Bibliografia, Referências e Links úteis

# %% [markdown]
# ### Projetos com Feedback
#
# - Projeto 11 - Desenvolvendo um Business Plan Com Base em Modelos Preditivos
# - Projeto 12 - Design de Arquitetura Para Projetos IoT Analytics

# %% [markdown]
# ### Avaliação
#
# - Leia Antes de Realizar a Avaliação Final
# - Certificado da Formação Cientista de Dados
# - Avaliação50 questões
